# %%
# Imports

from re import L
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data
metadata_file = "/Users/davidabelson/Library/CloudStorage/OneDrive-UniversityofCambridge/Aaron Weimann's files - project_k/data/final/metadata/metadata_final_curated_slimmed.tsv"
metadata = pd.read_csv(metadata_file, sep="\t", low_memory=False)
display(metadata.head)
# Out:
# <bound method NDFrame.head of                                   Sample  is_kpsc  kpsc_final_list  is_refseq  \
# 0                           SAMD00002693    False            False      False
# 1                           SAMD00008836    False            False      False
# 2                           SAMD00008944    False            False      False
# 3                           SAMD00009480    False            False      False
# 4                           SAMD00049595     True             True      False
# ...                                  ...      ...              ...        ...
# 88298  GCA_901421135.1_38502_B01_genomic     True             True      False
# 88299  GCA_901422025.1_38445_C01_genomic     True             True      False
# 88300  GCA_901422065.1_40345_F01_genomic     True             True      False
# 88301  GCA_901482715.1_42925_D01_genomic     True             True      False
# 88302  GCA_901542315.1_44087_B02_genomic     True             True      False
#
#        is_nctc                                            species  \
# 0        False                         Klebsiella ornithinolytica
# 1        False                               Klebsiella terrigena
# 2        False                                 Klebsiella oxytoca
# 3        False                               Klebsiella aerogenes
# 4        False                              Klebsiella pneumoniae
# ...        ...                                                ...
# 88298     True                              Klebsiella pneumoniae
# 88299     True  Klebsiella quasipneumoniae subsp. similipneumo...
# 88300     True                              Klebsiella pneumoniae
# 88301     True                              Klebsiella pneumoniae
# 88302     True                              Klebsiella pneumoniae
#
#       species_match  contig_count        N50  largest_contig  ...  \
# 0            strong           NaN        NaN             NaN  ...
# 1            strong           NaN        NaN             NaN  ...
# 2            strong           NaN        NaN             NaN  ...
# 3            strong           NaN        NaN             NaN  ...
# 4            strong         112.0   306529.0        695206.0  ...
# ...             ...           ...        ...             ...  ...
# 88298        strong           2.0  5165264.0       5165264.0  ...
# 88299        strong           1.0  5142131.0       5142131.0  ...
# 88300        strong           1.0  5208158.0       5208158.0  ...
# 88301        strong           5.0  3464261.0       3464261.0  ...
# 88302        strong           3.0  5196107.0       5196107.0  ...
#
#        host_parsed host_category collection_date collection_date_parsed  \
# 0              NaN           NaN             NaN                    NaN
# 1              NaN           NaN             NaN                    NaN
# 2              NaN           NaN             NaN                    NaN
# 3              NaN           NaN             NaN                    NaN
# 4            human         human      2009-01-01             2009/01/01
# ...            ...           ...             ...                    ...
# 88298          NaN           NaN            1953             1953/01/01
# 88299          NaN           NaN            1952             1952/01/01
# 88300          NaN           NaN            1952             1952/01/01
# 88301          NaN           NaN            1930             1930/01/01
# 88302          NaN           NaN            1948             1948/01/01
#
#       year_parsed dev_stage                       scientific_name center_name  \
# 0             NaN       NaN            Raoultella ornithinolytica    GIFU_MED
# 1             NaN       NaN  Klebsiella pneumoniae subsp. ozaenae    GIFU_MED
# 2             NaN       NaN                    Klebsiella oxytoca    GIFU_MED
# 3             NaN       NaN                  Klebsiella aerogenes    GIFU_MED
# 4          2009.0       NaN                 Klebsiella pneumoniae    KYOTO_GM
# ...           ...       ...                                   ...         ...
# 88298      1953.0       NaN                                   NaN         NaN
# 88299      1952.0       NaN                                   NaN         NaN
# 88300      1952.0       NaN                                   NaN         NaN
# 88301      1930.0       NaN                                   NaN         NaN
# 88302      1948.0       NaN                                   NaN         NaN
#
#       amr_study study_setting
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
# ...         ...           ...
# 88298       NaN           NaN
# 88299       NaN           NaN
# 88300       NaN           NaN
# 88301       NaN           NaN
# 88302       NaN           NaN
#
# [88303 rows x 152 columns]>

# %%
# Check sequence type ST
